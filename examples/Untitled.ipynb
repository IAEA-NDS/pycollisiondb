# %%
from pycollisiondb.pycollisiondb import PyCollision
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# Fetch datasets from the server over the API.
# Proton-impact ionization of H.
query = {'pks': [102737, 103103, 103104]}
pycoll = PyCollision.get_datasets(query=query)

# %%
pycoll.datasets
# Out:
# {102737: D102737: H+ + H 1s → H+ + H+ + e-,
#  103103: D103103: H 1s + H+ → H+ + H+ + e-,
#  103104: D103104: H 1s + H+ → H+ + H+ + e-}

# %%
ds = pycoll.datasets[103104]
ds.convert_units('sigma', 'a02')
ds.convert_units('E', 'keV.u-1')

# %%
fig, ax = plt.subplots()
ds.plot_dataset(ax, label_axes=True, use_latex=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
pycoll.plot_all_datasets(ax, label=('reaction', 'qid', 'refs', 'process_types'))
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# PyCollisionDBPlotError                    Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 fig, ax = plt.subplots()
# ----> 2 pycoll.plot_all_datasets(ax, label=('reaction', 'qid', 'refs', 'process_types'))
#       3 plt.legend()
#
# File ~/projects/pycollisiondb/src/pycollisiondb/pycollisiondb.py:296, in PyCollision.plot_all_datasets(self, ax, **kwargs)
#     295 def plot_all_datasets(self, ax, **kwargs):
# --> 296     self.plot_datasets(ax, self.all_pks, **kwargs)
#
# File ~/projects/pycollisiondb/src/pycollisiondb/pycollisiondb.py:304, in PyCollision.plot_datasets(self, ax, pks, reaction_texts, **kwargs)
#     299 if pks is None:
#     300     pks = [
#     301         pk for reaction_text in reaction_texts for pk in self.pks[reaction_text]
#     302     ]
# --> 304 data_type, columns = self._get_plot_metadata(pks)
#     306 for pk in pks:
#     307     self.datasets[pk].plot_dataset(ax, use_latex=self.use_latex, **kwargs)
#
# File ~/projects/pycollisiondb/src/pycollisiondb/pycollisiondb.py:326, in PyCollision._get_plot_metadata(self, pks)
#     322         raise PyCollisionDBPlotError(
#     323             "Energy frames not all the same in requested plot."
#     324         )
#     325     if self.datasets[pk].metadata["json_data"]["columns"] != columns:
# --> 326         raise PyCollisionDBPlotError(
#     327             "Column metadata not all the same in requested plot."
#     328         )
#     330 return data_type, columns
#
# PyCollisionDBPlotError: Column metadata not all the same in requested plot.

# %%
from pyqn.units import Units

# %%
ds = pycoll.datasets[103104]

# %%
ds.x, ds.y

# %%
ds.metadata

# %%
fu = ds.metadata['json_data']['columns'][1]['units']
fu = Units(fu)
tu = 'a02'
fu.conversion(tu)

# %%
from pyqn.units import convert

# %%
convert(ds.y, fu, tu)

# %%
ds.y * convert(fu, tu)

# %%
ds.unc_lo

# %%
pycoll.DATA_DIR

# %%
1.6e-18 * 3.5710648258636876e+16

# %%
ds.x

# %%
fu = Units('eV.u-1')

# %%
fu.conversion('keV.u-1')

# %%
ds.x *= 0.001

# %%
ds

# %%
ds.x
