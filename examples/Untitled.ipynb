# %%
from IPython.display import HTML, Latex
from pycollisiondb.pycollisiondb import PyCollision
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
query = {'pks': [102737]}
pycoll = PyCollision.get_datasets(query=query)

# %%
print(pycoll.datasets[102737].print_values())
# Out:
# E / eV.u-1 sigma / cm2
# 1000.0 5.471e-19
# 4000.0 1.96e-18
# 9000.0 1.235e-17
# 16000.0 4.05e-17
# 25000.0 9.192e-17
# 36000.0 1.405e-16
# 49000.0 1.628e-16
# 64000.0 1.605e-16
# 81000.0 1.45e-16
# 100000.0 1.248e-16

# %%
pycoll.convert_units({'E': 'keV.u-1', 'sigma': 'Mb'})

# %%
print(pycoll.datasets[102737].print_values())
# Out:
# E / keV.u-1 sigma / Mb
# 1.0 0.5471
# 4.0 1.9600000000000002
# 9.0 12.350000000000001
# 16.0 40.50000000000001
# 25.0 91.92000000000002
# 36.0 140.5
# 49.0 162.8
# 64.0 160.50000000000003
# 81.0 145.0
# 100.0 124.80000000000001

# %%
fig, ax = plt.subplots()
pycoll.datasets[102737].plot_dataset(ax)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'gtk4', 'wx', 'qt4', 'qt5', 'qt6', 'qt', 'osx', 'nbagg', 'webagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']
